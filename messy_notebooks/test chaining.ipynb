# %%
from dreye.stimuli.base import RandomizeChainedStimuli
from dreye.stimuli import StepStimulus

import matplotlib.pyplot as plt

# %%
import pint

# %%
pint.errors.DimensionalityError
# Out:
# pint.errors.DimensionalityError

# %%
step = StepStimulDimensionalityError
    values={
        'a':[1], 
        'b':[3]
    }, 
    rate=60, 
    start_delay=1, 
    end_dur=1, 
    pause_durations=[1, 2], 
    durations=[1, 2], 
    aligned_durations=True,
    separate_channels=True,
    repetitions=2
)

# %%
step.events
# Out:
#      a    b  dur  pause  repeat  iter  delay          name  fitted_a  fitted_b
# 0  1.0  0.0  1.0    1.0       0     0    1.0  StepStimulus       1.0       0.0
# 1  1.0  0.0  1.0    1.0       0     0    3.0  StepStimulus       1.0       0.0
# 2  1.0  0.0  2.0    2.0       0     0    5.0  StepStimulus       1.0       0.0
# 3  1.0  0.0  2.0    2.0       0     0    9.0  StepStimulus       1.0       0.0
# 4  0.0  3.0  1.0    1.0       1     0   13.0  StepStimulus       0.0       3.0
# 5  0.0  3.0  1.0    1.0       1     0   15.0  StepStimulus       0.0       3.0
# 6  0.0  3.0  2.0    2.0       1     0   17.0  StepStimulus       0.0       3.0
# 7  0.0  3.0  2.0    2.0       1     0   21.0  StepStimulus       0.0       3.0

# %%
step.values
# Out:
#      a    b
# 0  1.0  0.0
# 1  0.0  3.0

# %%
step.plot()
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a240a3e10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a242f8350>],
#       dtype=object)

# %%
rando = RandomizeChainedStimuli([step, step])

# %%
plt.figure(figsize=(15, 5))
plt.plot(rando.timestamps, rando.stimulus)
# Out:
# [<matplotlib.lines.Line2D at 0x1a244df890>,
#  <matplotlib.lines.Line2D at 0x1a244dfa90>]

# %%
rando.events
# Out:
#     index    a    b  delay  dur  fitted_a  fitted_b  iter          name  \
# 0      14  0.0  3.0    1.0  2.0       0.0       3.0     0  StepStimulus
# 1       2  1.0  0.0    5.0  2.0       1.0       0.0     0  StepStimulus
# 2      12  0.0  3.0    9.0  1.0       0.0       3.0     0  StepStimulus
# 3       3  1.0  0.0   11.0  2.0       1.0       0.0     0  StepStimulus
# 4      15  0.0  3.0   15.0  2.0       0.0       3.0     0  StepStimulus
# 5       5  0.0  3.0   19.0  1.0       0.0       3.0     0  StepStimulus
# 6       7  0.0  3.0   21.0  2.0       0.0       3.0     0  StepStimulus
# 7      10  1.0  0.0   25.0  2.0       1.0       0.0     0  StepStimulus
# 8      11  1.0  0.0   29.0  2.0       1.0       0.0     0  StepStimulus
# 9      13  0.0  3.0   33.0  1.0       0.0       3.0     0  StepStimulus
# 10      9  1.0  0.0   35.0  1.0       1.0       0.0     0  StepStimulus
# 11      8  1.0  0.0   37.0  1.0       1.0       0.0     0  StepStimulus
# 12      1  1.0  0.0   39.0  1.0       1.0       0.0     0  StepStimulus
# 13      6  0.0  3.0   41.0  2.0       0.0       3.0     0  StepStimulus
# 14      0  1.0  0.0   45.0  1.0       1.0       0.0     0  StepStimulus
# 15      4  0.0  3.0   47.0  1.0       0.0       3.0     0  StepStimulus
#
#     pause  repeat  stim_index
# 0     2.0       1           1
# 1     2.0       0           0
# 2     1.0       1           1
# 3     2.0       0           0
# 4     2.0       1           1
# 5     1.0       1           0
# 6     2.0       1           0
# 7     2.0       0           1
# 8     2.0       0           1
# 9     1.0       1           1
# 10    1.0       0           1
# 11    1.0       0           1
# 12    1.0       0           0
# 13    2.0       1           0
# 14    1.0       0           0
# 15    1.0       1           0
